# %%
import pandas as pd
import matplotlib.pyplot as plt

weather_data = pd.read_csv('weather_data.csv')
print(weather_data.keys())
#specific_columns = weather_data[["Location", "Temperature"]]
# print(specific_columns)

# weather_data.plot(kind = "line", x = "Location")
weather_data.plot(kind = "bar")
# weather_data["temp"].plot.pie()
plt.title('Weather Visualization')
plt.xlabel('Location')
plt.ylabel('Weather')
plt.show()

specific_columns = weather_data[["Location", " Temperature"]]
print(specific_columns)
# Out:
# Index(['Location', ' Temperature', ' Precipitation', ' Wind_Speed'], dtype='object')
#      Location   Temperature
# 0  Location_A            10
# 1  Location_B            30
